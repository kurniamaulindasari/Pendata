# %% [markdown]
# # Pengantar Konsep Dasar Data Mining
# ## 📌Latar Belakang
# Sekarang semua aktivitas kita menghasilkan data. Mulai dari belanja online, main media sosial, transaksi bank, sampai sistem akademik di kampus, semuanya menyimpan data. Setiap hari jumlah data terus bertambah dan semakin besar.
#
# Masalahnya, banyak data yang hanya disimpan tanpa benar-benar dimanfaatkan. Padahal di dalam data tersebut sebenarnya ada informasi penting, seperti pola kebiasaan, tren, atau hubungan tertentu yang bisa membantu dalam mengambil keputusan. Nah, di sinilah Penambangan Data (Data Mining) berperan.
#
# ## 🌟Definisi
# Penambangan data atau data mining adalah proses untuk mencari dan menemukan pola, hubungan, atau informasi penting dari kumpulan data yang berjumlah besar. Data pada dasarnya hanyalah kumpulan angka atau catatan yang belum memiliki arti jika tidak dianalisis. Melalui proses data mining, data mentah tersebut diolah menggunakan teknik tertentu sehingga menghasilkan informasi yang berguna dan dapat membantu dalam pengambilan keputusan.
#
# Istilah “penambangan” digunakan karena prosesnya mirip seperti menambang emas dari dalam tanah. Di antara banyaknya data yang tersimpan, terdapat informasi berharga yang tersembunyi. Dengan bantuan komputer dan metode analisis seperti statistik serta algoritma tertentu, informasi tersebut dapat digali dan dimanfaatkan.
#
# Jadi Data mining adalah teknik untuk mengubah data mentah menjadi informasi yang bermakna melalui proses analisis.
#
# ## 🎯Tujuan
# Tujuan data mining adalah untuk menemukan pola, hubungan, dan informasi tersembunyi dari kumpulan data yang besar sehingga dapat membantu dalam pengambilan keputusan. Data mining juga digunakan untuk membuat prediksi, mengelompokkan data, serta mendeteksi hal-hal yang tidak biasa dalam data.
#
# ## 💡Manfaat
# Data mining bermanfaat untuk membantu organisasi atau perusahaan memahami data yang mereka miliki. Dengan data mining, keputusan dapat dibuat lebih cepat, tepat, dan berdasarkan data nyata. Selain itu, data mining dapat meningkatkan efisiensi kerja, mengurangi risiko, serta membantu dalam menyusun strategi yang lebih efektif.
#
# ## 🏆Keunggulan
# Keunggulan data mining terletak pada kemampuannya mengolah data dalam jumlah besar dengan cepat dan akurat. Data mining juga mampu menemukan pola yang sulit dilihat secara manual serta membantu dalam melakukan prediksi berdasarkan data sebelumnya.
#
# ## 📋Tugas Utama
# Tugas utama data mining adalah menemukan pola, hubungan, dan informasi penting dari data dalam jumlah besar untuk mendukung pengambilan keputusan. Proses ini mencakup klasifikasi, prediksi, pengelompokan, dan deteksi anomali.
#
# ## 📊Prosess
# Dalam data mining, terdapat metode standar yang disebut CRISP-DM (Cross-Industry Standard Process for Data Mining). Metode ini merupakan model proses terbuka yang banyak digunakan oleh praktisi data mining untuk mengelola proyek secara sistematis.
#
# CRISP-DM menggambarkan siklus hidup proyek data mining yang terdiri dari beberapa tahapan, mulai dari pemahaman bisnis hingga evaluasi dan implementasi. Setiap tahap memiliki tugas tertentu dan saling terhubung satu sama lain.
#
# ![image.png](data:image/png;base64,...)
#
# ## 1️⃣ Memahami Bisnis (Business Understanding)
# Business Understanding adalah tahap awal dalam proses data mining yang berfokus pada memahami masalah dan tujuan bisnis sebelum melakukan analisis data. Tahap ini merupakan bagian pertama dari metodologi CRISP-DM. Pada fase ini, analis tidak langsung mengolah data, tetapi memahami kebutuhan organisasi dan menerjemahkannya menjadi tujuan analitis yang jelas dan terukur.
#
# - Menentukan Tujuan Bisnis (Determine Business Objectives)
#
# Tahap ini berfokus pada identifikasi masalah utama dan penetapan tujuan bisnis yang jelas serta terukur melalui diskusi dengan pihak terkait. Tujuan tersebut menjadi dasar arah proyek dan tolok ukur keberhasilan dari sisi bisnis.
# - Menganalisis Situasi (Assess Situation)
#
# Pada tahap ini dilakukan peninjauan kondisi proyek, termasuk sumber daya, waktu, biaya, risiko, dan keterbatasan yang ada. Analisis ini membantu memastikan proyek layak dan realistis untuk dilaksanakan.
#
# - Menentukan Tujuan Data Mining (Determine Data Mining Goals)
#
# Tahap ini menerjemahkan tujuan bisnis ke dalam tujuan teknis yang dapat dianalisis menggunakan data, seperti menentukan jenis model dan metode evaluasi. Hal ini memastikan hasil analisis mendukung kebutuhan bisnis.
#
# - Menyusun Rencana Proyek (Produce Project Plan)
#
# Tahap ini meliputi penyusunan rencana kerja secara sistematis, termasuk jadwal, pembagian tugas, dan tahapan pengerjaan. Perencanaan yang baik membantu proyek berjalan terarah dan efisien.
#
# ## 2️⃣ Memahami data (data understanding)
# Data Understanding adalah tahap setelah Business Understanding yang bertujuan untuk memahami data yang akan digunakan dalam proyek. Pada tahap ini, tim mulai mengumpulkan data, mengenali struktur dan karakteristiknya, serta mengidentifikasi kualitas data sebelum masuk ke proses pengolahan lebih lanjut.
#
# - Mengumpulkan Data (Collect Initial Data)
#
# Tahap ini dilakukan dengan mengumpulkan data dari berbagai sumber yang relevan dengan tujuan proyek, seperti database, file, atau sistem internal perusahaan. Proses ini memastikan data yang digunakan sesuai dengan kebutuhan analisis.
#
# - Mendeskripsikan Data (Describe Data)
#
# Pada tahap ini dilakukan pengenalan terhadap struktur data, seperti jumlah atribut, tipe data, jumlah record, serta gambaran umum isi data. Tujuannya adalah memahami bentuk dan karakteristik dasar dari data yang tersedia.
#
# - Mengeksplorasi Data (Explore Data)
#
# Tahap ini bertujuan untuk menemukan pola awal, hubungan antar variabel, atau indikasi masalah melalui analisis sederhana seperti statistik deskriptif atau visualisasi. Proses ini membantu memahami perilaku data secara lebih mendalam.
#
# - Memverifikasi Kualitas Data (Verify Data Quality)
#
# Pada tahap ini dilakukan pemeriksaan terhadap kelengkapan, konsistensi, dan akurasi data, seperti mendeteksi nilai kosong, data duplikat, atau kesalahan input. Tujuannya adalah memastikan data layak digunakan untuk tahap selanjutnya.
#
# ## Data Understanding Iris flower
# 1. Collect Initial Data (Pengumpulan Data Awal)
# Langkah pertama dalam tahap ini adalah memperoleh data yang akan dianalisis. Data yang digunakan berasal dari Iris dataset yang tersedia dalam bentuk file CSV dengan nama IRIS.csv.
#
# Dataset diambil dari sumber publik yang umum digunakan untuk penelitian klasifikasi.
# Data terdiri dari 150 sampel bunga Iris.
# Terdapat tiga kelas atau spesies bunga, yaitu:
# Iris-setosa
# Iris-versicolor
# Iris-virginica
#
# Dataset memiliki lima atribut, yaitu:
# sepal_length
# sepal_width
# petal_length
# petal_width
# species
#
# - Dilakukan pengecekan jumlah data (baris) dan jumlah atribut (kolom).
#
# - Dilakukan identifikasi tipe data untuk membedakan atribut numerik dan kategorikal.
#
# - Memastikan proses pemuatan data berjalan dengan baik tanpa kesalahan.
# Tahapan ini bertujuan memastikan data telah terkumpul secara lengkap, sesuai kebutuhan, dan siap untuk dianalisis pada tahap berikutnya
#
# 2. Describe Data (Deskripsi Data)
# Setelah data berhasil dikumpulkan, tahap berikutnya adalah memahami karakteristik dan struktur dataset tersebut.
#
# Dataset memiliki 150 baris dan 5 kolom. Empat kolom pertama berisi data numerik (float), sedangkan satu kolom terakhir berisi data kategorikal.
#
# Rincian atributnya adalah:
#
# sepal_length → panjang kelopak bunga dalam centimeter
# sepal_width → lebar kelopak bunga dalam centimeter
# petal_length → panjang mahkota bunga dalam centimeter
# petal_width → lebar mahkota bunga dalam centimeter
# species → jenis bunga Iris
#
# Setiap baris merepresentasikan satu bunga. Dari hasil pengecekan awal, tidak ditemukan nilai kosong pada dataset.
#
# Dengan memahami struktur ini, proses analisis dapat dilakukan dengan lebih terarah.
#
# 3. Eksplorasi Data (Data Exploration)
# Tahap eksplorasi bertujuan untuk melihat pola awal serta hubungan antar variabel dalam dataset.
#
# kegiatan yang dilakukan pada tahap ini adalah:
#
# - Mengamati sebaran nilai pada atribut numerik
# - Membandingkan ukuran bunga berdasarkan masing-masing spesies
# - Mengidentifikasi kemungkinan perbedaan
# - karakteristik antar kelas
#
# Analisis dilakukan menggunakan statistik deskriptif seperti rata-rata, median, nilai minimum, maksimum, serta standar deviasi. Selain itu, visualisasi data seperti histogram, boxplot, dan scatter plot digunakan untuk melihat distribusi dan pola penyebaran data.
#
# Tahap ini membantu memberikan gambaran awal mengenai potensi pemisahan kelas berdasarkan atribut yang tersedia.
#
# 4. Verify Data Quality (Verifikasi Kualitas Data)
# Langkah terakhir dalam tahap Data Understanding adalah memastikan kualitas data sebelum masuk ke proses pemodelan.
#
# - Mengecek keberadaan missing value.
# - Mengidentifikasi kemungkinan data duplikat.
# - Memastikan tipe data sudah sesuai (numerik dan kategorikal).
# - Memastikan jumlah data tetap 150 baris sesuai dataset asli.
# - Memastikan tidak ada kesalahan dalam proses pembacaan file.
#
# Tahap ini penting untuk menjamin bahwa data yang digunakan dalam proses analisis memiliki kualitas yang baik dan tidak menimbulkan kesalahan pada tahap berikutnya.
#
# ## Eksplorasi Iris flower menggunakan Orange
# ![image.png](data:image/png;base64,...)
#
# 🔹 File
# Widget File digunakan untuk memuat dataset Iris ke dalam Orange. Setelah file berhasil dibuka, sistem mengenali 150 baris data dengan 5 variabel (4 fitur numerik dan 1 variabel target/kategori).
# ![image.png](data:image/png;base64,...)
#
# File IRIS.csv berhasil dibaca oleh Orange dengan total 150 baris data. Terdapat 4 variabel numerik sebagai fitur (sepal dan petal) serta 1 variabel kategorikal (species) yang ditetapkan sebagai target. Tidak ditemukan missing value, sehingga dataset siap digunakan untuk proses analisis berikutnya.
#
# 🔹 Select Columns
# Pada tahap ini dilakukan pengaturan peran atribut. Empat atribut ukuran bunga dijadikan sebagai fitur (input), sedangkan species ditetapkan sebagai variabel target (class). Pemisahan ini penting untuk analisis klasifikasi dan evaluasi fitur.
#
# 🔹 Data Table
# Widget ini berfungsi untuk menampilkan seluruh isi dataset dalam bentuk tabel. Melalui tampilan ini dapat dicek kembali struktur data, memastikan tidak ada data kosong, serta melihat contoh nilai pada setiap atribut.
# ![image.png](data:image/png;base64,...)
#
# Di bagian Data Table ini kita bisa lihat langsung isi dataset Iris secara lengkap. Total ada 150 data, dan semuanya terbaca dengan baik tanpa ada data yang kosong. Jadi nggak perlu pembersihan data lagi di tahap ini.
#
# Kolomnya ada lima. Empat kolom berisi angka yang menunjukkan ukuran bagian bunga (panjang dan lebar sepal serta petal), dan satu kolom terakhir yaitu species yang berisi jenis bunganya. Jenisnya ada tiga: Iris-setosa, Iris-versicolor, dan Iris-virginica.
#
# Setiap baris itu mewakili satu bunga iris lengkap dengan ukurannya dan label jenisnya. Karena datanya sudah rapi dan lengkap, dataset ini langsung bisa dipakai untuk analisis selanjutnya, misalnya untuk melihat pola atau membuat model klasifikasi.
#
# 🔹 Column Statistics
# Bagian ini memberikan gambaran statistik dari masing-masing atribut numerik, seperti nilai rata-rata, nilai minimum dan maksimum, serta distribusi data. Informasi ini membantu memahami karakteristik awal setiap fitur.
# ![image.png](data:image/png;base64,...)
#
# Di bagian Column Statistics, kita bisa lihat ringkasan angka-angka penting dari setiap kolom di dataset Iris. Jadi di sini bukan cuma lihat datanya satu per satu, tapi langsung dirangkum supaya lebih gampang dipahami.
#
# Pertama ada mean atau rata-rata. Ini nunjukin nilai rata-rata dari semua data di tiap variabel. Dari sini kita bisa tahu ukuran umum bunga iris. Misalnya, rata-rata panjang sepal ada di kisaran 5–6 cm.
#
# Lalu ada median, yaitu nilai tengah setelah data diurutkan. Median ini biasanya dipakai buat memastikan pusat data, apalagi kalau ada nilai yang terlalu kecil atau terlalu besar.
#
# Selanjutnya mode, yaitu nilai yang paling sering muncul. Ini membantu kita melihat angka yang paling umum dalam satu variabel.
#
# Ada juga nilai minimum dan maksimum, yang nunjukin batas paling kecil dan paling besar dari data. Dari situ kita bisa tahu seberapa lebar jarak variasi datanya.
#
# Kemudian bagian dispersion, ini menunjukkan seberapa menyebar datanya. Kalau angkanya makin besar, berarti variasinya juga makin besar. Dari hasil yang terlihat, bagian petal (panjang dan lebar mahkota) variasinya lebih besar dibandingkan sepal, artinya ukuran petal lebih beragam antar spesies.
#
# Terakhir, bagian missing value menunjukkan apakah ada data yang kosong. Di dataset ini semuanya 0%, jadi datanya lengkap dan bisa langsung dipakai tanpa perlu dibersihkan lagi.
#
# 🔹 Rank
# Widget Rank digunakan untuk mengevaluasi tingkat pengaruh masing-masing fitur terhadap variabel kelas. Hasil analisis biasanya menunjukkan bahwa atribut petal (petal_length dan petal_width) memiliki kontribusi paling besar dalam membedakan spesies Iris.
# ![image.png](data:image/png;base64,...)
#
# Di bagian Rank ini, kita bisa lihat fitur mana yang paling kuat pengaruhnya buat membedakan jenis bunga iris. Di sini aku pakai metode Information Gain Ratio dan Gini Decrease untuk ngukur seberapa penting tiap variabel.
#
# Dari hasil yang muncul, yang paling atas itu petal_length, disusul petal_width. Nilainya paling tinggi dibanding yang lain, jadi bisa dibilang dua fitur ini paling “ngebedain” antar spesies.
#
# Di bawahnya ada sepal_length, lalu terakhir sepal_width yang nilainya paling kecil. Artinya, ukuran sepal nggak terlalu kuat kalau dipakai sendirian buat membedakan jenis iris.
#
# 🔹 Scatter Plot
# Melalui Scatter Plot, hubungan antara dua variabel numerik dapat divisualisasikan dalam bentuk grafik titik. Dari visualisasi ini terlihat bahwa spesies Iris-setosa terpisah cukup jelas dari dua spesies lainnya, terutama jika menggunakan atribut petal.
# ![image.png](data:image/png;base64,...)
# Di grafik Scatter Plot ini, yang dibandingkan adalah panjang petal di sumbu mendatar (X) dan lebar petal di sumbu tegak (Y). Jadi kita bisa langsung lihat hubungan antara dua ukuran mahkota bunga tersebut.
#
# Setiap bulatan di grafik mewakili satu bunga, dan warnanya menunjukkan jenisnya. Dari tampilannya, langsung kelihatan kalau kelompok biru (Iris-setosa) ngumpul sendiri di bagian kiri bawah. Ukuran petalnya memang paling kecil, jadi posisinya jauh dari dua jenis lainnya.
#
# Kelompok merah (Iris-versicolor) ada di tengah-tengah, sedangkan yang hijau (Iris-virginica) cenderung ada di kanan atas karena ukuran petalnya paling besar. Versicolor dan virginica memang agak berdekatan, tapi masih bisa dibedakan karena virginica umumnya punya nilai yang lebih tinggi.
#
# Dari grafik ini kelihatan jelas banget kalau cuma dengan dua variabel petal saja, tiga jenis iris sudah bisa dipisahkan dengan cukup rapi. Ini makin menunjukkan kalau ukuran petal memang paling berperan dalam membedakan spesies bunga iris.
#
# 🔹 Box Plot
# Box Plot digunakan untuk membandingkan distribusi nilai setiap atribut berdasarkan spesies. Dari grafik ini dapat diamati perbedaan median, rentang data, serta kemungkinan adanya outlier pada masing-masing kelas.
# ![image.png](data:image/png;base64,...)
#
# Box Plot ini yang ditampilkan adalah ringkasan sebaran nilai untuk variabel petal_length. Jadi kita nggak lagi lihat titik satu per satu, tapi langsung gambaran besarnya.
#
# Dari grafiknya kelihatan batas paling kecil dan paling besar nilai panjang petal. Nilai terendahnya sekitar 1 cm, sedangkan yang paling tinggi mendekati 7 cm. Bagian kotaknya menunjukkan area di mana sebagian besar data terkumpul, kira-kira di rentang 1.6 sampai 5.1 cm.
#
# Garis di tengah kotak itu median (nilai tengah), sekitar 4.350, sedangkan rata-ratanya ada di sekitar 3.759. Dari panjang kotak dan garisnya, bisa dilihat kalau variasi panjang petal cukup lebar.
#
# Artinya, ukuran mahkota bunga dalam dataset ini cukup beragam. Variasi yang besar ini juga menjelaskan kenapa petal_length jadi salah satu variabel yang penting untuk membedakan jenis iris.
#
# 🔹 Correlations
# Widget ini menampilkan tingkat hubungan antar atribut numerik. Korelasi yang tinggi biasanya terlihat antara petal_length dan petal_width, yang menunjukkan keduanya memiliki hubungan linear yang kuat.
# ![image.png](data:image/png;base64,...)
#
# Correlations, kita bisa lihat seberapa saling berhubungannya antar ukuran bunga di dataset Iris. Di sini dipakai korelasi Pearson, jadi yang diukur itu hubungan linier antar dua variabel angka.
#
# Nilainya berkisar dari -1 sampai +1. Kalau angkanya makin mendekati +1 berarti hubungannya searah dan kuat. Kalau mendekati -1 berarti berlawanan arah. Kalau dekat 0 artinya hampir nggak ada hubungan.
#
# Dari hasil yang muncul, hubungan paling kuat itu antara petal_length dan petal_width dengan nilai sekitar +0.963. Artinya, kalau panjang petalnya besar, biasanya lebarnya juga ikut besar.
#
# Hubungan yang cukup kuat juga terlihat antara petal_length dan sepal_length (+0.872), serta petal_width dan sepal_length (+0.818).
#
# Sementara itu, sepal_width justru cenderung punya hubungan negatif dengan variabel petal. Misalnya petal_length dengan sepal_width nilainya sekitar -0.421. Artinya, saat panjang petal bertambah, lebar sepal cenderung sedikit menurun, walaupun hubungannya nggak terlalu kuat.
#
# Yang paling lemah hubungannya adalah sepal_length dan sepal_width (-0.109), hampir nggak ada keterkaitan yang berarti.
#
# Dari sini kelihatan kalau ukuran petal itu saling berkaitan sangat erat dibandingkan ukuran sepal. Makanya, variabel petal sering jadi fitur yang lebih kuat dan lebih informatif saat dipakai untuk analisis atau klasifikasi.
#
# 🔹 Pivot Table
# Pivot Table dimanfaatkan untuk merangkum jumlah data pada setiap kelas. Hasilnya menunjukkan distribusi yang seimbang, yaitu masing-masing spesies memiliki 50 sampel.
# ![image.png](data:image/png;base64,...)
#
# Pivot Table ini, fokusnya bukan lagi ke hubungan antar variabel, tapi ke komposisi datanya. Tabel tersebut memperlihatkan berapa banyak sampel yang dimiliki masing-masing spesies dalam dataset Iris.
#
# Dari tabel terlihat jelas bahwa setiap jenis bunga memiliki jumlah yang identik, yaitu 50 data untuk Iris-setosa, 50 data untuk Iris-versicolor, dan 50 data untuk Iris-virginica. Jika dijumlahkan, totalnya menjadi 150 data.
#
# Kalau dilihat dari sudut pandang analisis data, kondisi ini bisa dibilang ideal. Tidak ada kelas yang mendominasi atau kekurangan jumlah sampel. Jadi ketika nanti dataset ini digunakan untuk pelatihan model klasifikasi, peluang tiap kelas untuk dipelajari model itu sama besar.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-61e3af59-f165-4f2d-9af5-0898eb3196c4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-61e3af59-f165-4f2d-9af5-0898eb3196c4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv("IRIS.csv")
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
df = pd.read_csv('IRIS.csv')
df.head(150)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure()
sns.scatterplot(
    x='petal_length',
    y='petal_width',
    hue='species',
    data=df
)

plt.title("Scatter Plot Petal Length vs Petal Width")
plt.show()

# %%
corr_matrix = df.corr(numeric_only=True)
corr_matrix
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.109369      0.871754     0.817954
# sepal_width      -0.109369     1.000000     -0.420516    -0.356544
# petal_length      0.871754    -0.420516      1.000000     0.962757
# petal_width       0.817954    -0.356544      0.962757     1.000000

# %%
import pandas as pd
from scipy import stats

df = pd.read_csv("IRIS.csv")
df_numeric = df.select_dtypes(include=['int64','float64'])

for col in df_numeric.columns:
    print("===== Statistik untuk", col, "=====")
    print("Jumlah Data      :", df[col].count())
    print("Rata-rata        :", df[col].mean())
    print("Nilai Minimum    :", df[col].min())
    print("Q1               :", df[col].quantile(0.25))
    print("Median (Q2)      :", df[col].quantile(0.5))
    print("Q3               :", df[col].quantile(0.75))
    print("Nilai Maximum    :", df[col].max())
    print("Kemencengan      :", round(df[col].skew(), 6))

    mode = stats.mode(df[col], keepdims=True)
    print("Modus            :", mode.mode[0], "dengan jumlah", mode.count[0])

    print("Standar Deviasi  :", round(df[col].std(), 6))
    print("Variansi         :", round(df[col].var(), 6))
    print("\n")
# Out:
# ===== Statistik untuk sepal_length =====
# Jumlah Data      : 150
# Rata-rata        : 5.843333333333334
# Nilai Minimum    : 4.3
# Q1               : 5.1
# Median (Q2)      : 5.8
# Q3               : 6.4
# Nilai Maximum    : 7.9
# Kemencengan      : 0.314911
# Modus            : 5.0 dengan jumlah 10
# Standar Deviasi  : 0.828066
# Variansi         : 0.685694
#
#
# ===== Statistik untuk sepal_width =====
# Jumlah Data      : 150
# Rata-rata        : 3.0540000000000003
# Nilai Minimum    : 2.0
# Q1               : 2.8
# Median (Q2)      : 3.0
# Q3               : 3.3
# Nilai Maximum    : 4.4
# Kemencengan      : 0.334053
# Modus            : 3.0 dengan jumlah 26
# Standar Deviasi  : 0.433594
# Variansi         : 0.188004
#
#
# ===== Statistik untuk petal_length =====
# Jumlah Data      : 150
# Rata-rata        : 3.758666666666666
# Nilai Minimum    : 1.0
# Q1               : 1.6
# Median (Q2)      : 4.35
# Q3               : 5.1
# Nilai Maximum    : 6.9
# Kemencengan      : -0.274464
# ...

# %% [markdown]
# ## Mengukur Jarak dengan Tipe Data Campuran
# Mengukur jarak dengan tipe data campuran adalah proses menghitung tingkat kemiripan atau perbedaan antara dua objek data yang memiliki lebih dari satu jenis tipe data dalam satu dataset.
#
# Sebelum mengitung jarak di data campuran, kita harus paham dulu istilah-istilah dasar kayak objek, atribut, dimensi, fitur, dan variabel.
# | Konsep              | Pengertian                                       | Hubungan dalam Analisis                           |
# | ------------------- | ------------------------------------------------ | ------------------------------------------------- |
# | **Objek**           | Entitas atau data yang diamati (baris data)      | Dibandingkan satu sama lain dalam proses analisis |
# | **Atribut**         | Karakteristik yang mendeskripsikan objek         | Menjadi dasar perhitungan jarak                   |
# | **Dimensi**         | Sebutan atribut dalam konteks ruang multidimensi | Menunjukkan jumlah atribut yang digunakan         |
# | **Fitur (Feature)** | Istilah atribut dalam machine learning           | Digunakan sebagai input algoritma                 |
# | **Variabel**        | Istilah atribut dalam statistik                  | Digunakan dalam pengolahan dan analisis data      |
#
# Nah, setiap atribut juga punya karakteristik beda-beda. Ada yang angka, ada yang kategori, ada yang punya urutan. Cara ngitung jaraknya ya beda-beda sesuai tipe datanya.
#
# | Tipe Atribut        | Pengertian                                               | Karakteristik Utama                           | Peran dalam Perhitungan Jarak                    |
# | ------------------- | -------------------------------------------------------- | --------------------------------------------- | ------------------------------------------------ |
# | **Numerik**         | Atribut berbentuk angka yang memiliki makna matematis    | Dapat dilakukan operasi aritmatika            | Dihitung menggunakan rumus jarak numerik         |
# | **Nominal**         | Atribut berbentuk kategori tanpa urutan                  | Tidak memiliki tingkatan                      | Dibandingkan berdasarkan kesamaan atau perbedaan |
# | **Ordinal**         | Atribut kategori yang memiliki urutan                    | Memiliki tingkatan tetapi selisih tidak pasti | Diubah ke bentuk ranking sebelum dihitung        |
# | **Biner Simetris**  | Atribut dengan dua nilai yang sama penting               | Kedua nilai memiliki bobot yang setara        | Menggunakan perhitungan kesamaan sederhana       |
# | **Biner Asimetris** | Atribut dengan dua nilai tetapi salah satu lebih penting | Fokus pada kemunculan nilai tertentu          | Menggunakan ukuran kesamaan khusus               |
#
# Untuk menghitung jarak pada data dengan tipe atribut yang berbeda-beda (mixed data), salah satu metode yang dapat digunakan adalah Gower Distance. Metode ini dikembangkan oleh J. C. Gower pada tahun 1971.
#
# - Rumus Gower Distance
#
# Ukuran jarak Gower menghitung tingkat ketidakmiripan antara dua objek dengan cara merata-ratakan kontribusi dari setiap atribut.
#
# $$
# D_{ij} = \frac{1}{p} \sum_{k=1}^{p} d_{ijk}
#  $$
#
# Keterangan:
#
# - $D_{ij}$ = jarak antara objek $i$ dan $j$
# - $p$ = jumlah total atribut
# - $s_{ijk}$ = nilai ketidakmiripan pada atribut ke-$k$
#
# Nilai jarak berada pada interval:
#
# $$
# 0 \leq D_{ij} \leq 1
# $$
#
# - 0 → kedua objek identik
# - 1 → kedua objek sepenuhnya berbeda
#
# **contoh perhitngan**
# | Objek | Usia | Kota     | Status  |
# | ----- | ---- | -------- | ------- |
# | X     | 25   | Surabaya | Menikah |
# | Y     | 35   | Jakarta  | Menikah |
#
# Diketahui rentang usia dalam dataset adalah 20–40, sehingga:
# $$R = 40 - 20 = 20$$
#
# ---
# 1. Atribut Numerik (Usia)
# Menghitung selisih absolut yang dinormalisasi dengan rentang ($R$):
# $$d_1 = \frac{|25 - 35|}{20} = \frac{10}{20} = 0.5$$
# 2. Atribut Kategorikal (Kota)
# Karena data bersifat nominal dan nilainya **berbeda**:
# $$d_2 = 1$$
# 3. Atribut Kategorikal (Status)
# Karena data bersifat nominal dan nilainya **sama**:
# $$d_3 = 0$$
# 4. Hitung Jarak Total
# Jarak total ($D_{XY}$) dihitung dengan merata-ratakan seluruh jarak atribut:
# $$D_{XY} = \frac{d_1 + d_2 + d_3}{3}$$
# $$D_{XY} = \frac{0.5 + 1 + 0}{3} = \frac{1.5}{3}$$
# $$D_{XY} = 0.5$$
#
# > **Kesimpulan:** Nilai 0.5 menunjukkan bahwa objek X dan Y memiliki tingkat perbedaan sedang (tidak terlalu mirip tetapi juga tidak sepenuhnya berbeda).
#
# Keunggulan Gower Distance
# - Dapat digunakan pada dataset dengan tipe atribut beragam
# - Skala numerik dinormalisasi sehingga adil
# - Sesuai untuk metode clustering seperti hierarchical clustering
# - Bisa diterapkan pada algoritma KNN untuk data campuran
# - Mampu menangani missing value
#
# Keterbatasan Gower Distance
# - Dipengaruhi oleh rentang nilai pada atribut numerik
# - Jika atribut kategorikal dominan, nilai jarak bisa cenderung besar
# - Data ordinal perlu diubah menjadi ranking terlebih dahulu
# - Semua atribut memiliki bobot sama (kecuali ditambahkan pembobotan khusus)
#
# ## Analisis dan Implementasi Data Campuran Menggunakan Orange (Dataset Iris)
# ![image.png](data:image/png;base64,...)
#
# Adapun widget yang digunakan adalah:
# - File (Input data)
# - Select Columns (Pengaturan fitur)
# - Box Plot (Visualisasi distribusi)
# - Distances (Kalkulasi matriks jarak)
# - Distance Map, MDS, & Hierarchical Clustering (Analisis pengelompokan)
#
# ![image.png](data:image/png;base64,...)
# 🔹Pada tampilan **File** di Orange terlihat bahwa dataset **IRIS.csv** sudah berhasil dimasukkan ke dalam sistem. Jumlah datanya ada **150 baris** dengan total **5 atribut**.
#
# Empat atribut pertama yaitu **sepal_length, sepal_width, petal_length,** dan **petal_width** bertipe **numerik**, artinya isinya berupa angka dan digunakan sebagai variabel input (fitur).
#
# Sedangkan satu atribut terakhir yaitu **species** bertipe **kategorikal** dan dijadikan sebagai **target/kelas**. Nilainya terdiri dari tiga jenis bunga: **Iris-setosa, Iris-versicolor,** dan **Iris-virginica**.
#
# Di bagian informasi juga terlihat bahwa **tidak ada data yang kosong (missing value)**, jadi dataset ini lengkap dan siap langsung dipakai untuk proses analisis atau pemodelan.
#
# ![image.png](data:image/png;base64,...)
#
# 🔹 Pada **Select Columns**, setiap kolom dipisahkan sesuai fungsinya dalam analisis.
#
# Empat kolom numerik yaitu **sepal_length, sepal_width, petal_length,** dan **petal_width** dimasukkan ke bagian **Features**. Kolom-kolom ini yang akan dipakai dalam proses perhitungan, misalnya saat menghitung jarak antar data.
#
# Sementara itu, kolom **species** yang bertipe kategorikal dimasukkan ke bagian **Target**. Kolom ini berperan sebagai label kelas, biasanya digunakan untuk membedakan atau memberi warna pada hasil visualisasi.
#
# Dengan pembagian seperti ini, Orange bisa membedakan mana data yang benar-benar dipakai untuk proses perhitungan dan mana yang hanya digunakan sebagai penanda atau pembeda kelas pada tampilan hasilnya.
#
# ![image.png](data:image/png;base64,...)
#
# 🔹 Pada **Distances**, di sinilah proses perhitungan jarak antar data dilakukan.
#
# Opsi **Rows** dipilih karena yang ingin dibandingkan adalah setiap baris data, artinya tiap sampel bunga dibandingkan satu sama lain. Jadi bukan atributnya yang dibandingkan, tapi objek bunganya.
#
# Metode yang digunakan adalah **Euclidean (normalized)**. Karena semua fitur bertipe numerik tapi rentang nilainya berbeda-beda, maka dilakukan normalisasi terlebih dahulu supaya tidak ada satu variabel yang terlalu mendominasi perhitungan jarak. Dengan begitu, hasilnya lebih seimbang.
#
# Output dari proses ini adalah matriks berukuran **150 × 150**. Maksudnya, setiap dari 150 data dihitung jaraknya terhadap 149 data lainnya, sehingga terbentuk tabel jarak lengkap antar seluruh sampel. Matriks ini nantinya bisa dipakai untuk analisis lanjutan seperti clustering atau visualisasi hubungan antar data.
#
# ![image.png](data:image/png;base64,...)
# 🔹Pada **MDS**, hasil matriks jarak tadi diubah menjadi tampilan visual dua dimensi. Jadi jarak yang awalnya berbentuk angka-angka di matriks sekarang dipetakan menjadi titik-titik pada grafik supaya lebih mudah dibaca.
#
# Angka **Kruskal Stress = 0,051** menandakan kualitas proyeksi ini sangat baik. Karena nilainya jauh di bawah 0,15, berarti susunan titik di grafik sudah cukup merepresentasikan jarak aslinya. Dengan kata lain, posisi antar titik di plot tidak terlalu menyimpang dari perhitungan jarak sebenarnya.
#
# Setiap titik diberi warna sesuai dengan kolom **species**, sehingga masing-masing jenis bunga bisa dibedakan dengan jelas. Opsi **Show legend** yang diaktifkan membuat keterangan warna muncul di samping grafik, jadi kita langsung tahu warna mana mewakili Setosa, Versicolor, atau Virginica.
#
# Kalau dilihat dari penyebaran titiknya, **Setosa** tampak terpisah dan membentuk kelompok sendiri. Sedangkan **Versicolor** dan **Virginica** posisinya lebih berdekatan. Meskipun begitu, keduanya masih bisa dibedakan karena tidak benar-benar menyatu dalam satu kumpulan titik.
#
# ![image.png](data:image/png;base64,...)
#
# 🔹Pada **Box Plot**, data ditampilkan dalam bentuk diagram kotak yang memperlihatkan sebaran nilai, median, serta rentang tiap kelompok.
#
# Di bagian **Variable**, kita bisa memilih atribut yang ingin dianalisis, misalnya **petal_length**. Setelah itu, bagian **Subgroups** diisi dengan **species** supaya grafiknya otomatis dipisah berdasarkan jenis bunga.
#
# Dari hasil tampilannya terlihat perbedaan yang cukup jelas. Nilai **petal_length** pada **Setosa** cenderung paling kecil, **Versicolor** ada di tengah, dan **Virginica** paling besar. Meski begitu, antara **Versicolor** dan **Virginica** masih ada sedikit bagian yang saling tumpang tindih, jadi tidak sepenuhnya terpisah sempurna.
#
# ![image.png](data:image/png;base64,...)
# 🔹Pada **Hierarchical Clustering**, hasil perhitungan jarak ditampilkan dalam bentuk **dendrogram** atau diagram pohon. Grafik ini menunjukkan bagaimana tiap sampel saling bergabung berdasarkan tingkat kemiripannya.
#
# Metode **Linkage** yang dipakai adalah **Ward**. Cara kerja Ward itu mengelompokkan data dengan meminimalkan variasi dalam satu kelompok, jadi data yang digabung benar-benar yang paling mirip.
#
# Bagian **Annotations** diisi dengan **species**, supaya setiap sampel punya label jenis bunganya. Lalu di bagian **Color by** juga dipilih **species**, jadi warna cabangnya mengikuti kategori bunga masing-masing. Ini bikin hasilnya lebih gampang dibaca.
#
# Dari dendrogram terlihat ada tiga kelompok utama. Satu kelompok besar berisi seluruh **Setosa** yang langsung menyatu dalam satu cabang. Sementara itu, kelompok lainnya terbagi lagi menjadi dua bagian yang mewakili **Versicolor** dan **Virginica**. Ini menunjukkan kalau **Setosa** memang paling berbeda dibanding dua jenis lainnya, sedangkan **Versicolor** dan **Virginica** masih punya kemiripan yang cukup dekat.
#
# ![image.png](data:image/png;base64,...)
# 🔹Di **Distance Map**, hasil perhitungan jarak tadi ditampilkan sebagai peta warna, jadi kita bisa langsung melihat pola kedekatan antar data tanpa harus membaca angka satu per satu.
#
# Saat opsi **Clustering** diaktifkan, urutan data otomatis disusun ulang supaya sampel yang mirip saling berdekatan. Skala warnanya juga membantu: warna gelap (biru) berarti jaraknya dekat, sedangkan warna lebih terang mengindikasikan jaraknya makin jauh.
#
# Dari tampilannya terlihat jelas ada tiga kotak gelap yang membentuk pola di garis diagonal. Itu menandakan bahwa dalam satu **species**, data-datanya saling berdekatan. Sebaliknya, area di luar diagonal cenderung lebih terang, yang artinya jarak antar species memang lebih besar. Pola ini memperkuat bahwa tiap kelompok bunga punya ciri yang berbeda.
#
# dataset **Iris** diolah di Orange dengan menghitung jarak memakai metode **Euclidean (normalized)** lewat widget **Distances**, menghasilkan matriks 150×150. Ketika divisualisasikan menggunakan **MDS**, **Hierarchical Clustering**, sampai **Distance Map**, semuanya menunjukkan pola yang konsisten: terbentuk tiga kelompok utama sesuai dengan jenis bunganya.

# %% [markdown]
# ## 3️⃣ Persiapan Data (Data Preparation)
# Data Preparation adalah tahap yang bertujuan untuk menyiapkan data agar siap digunakan dalam proses pemodelan. Pada tahap ini, data yang sebelumnya telah dipahami akan dibersihkan, dipilih, dan diubah ke dalam format yang sesuai sehingga dapat menghasilkan model yang akurat dan optimal.
#
# - Memilih Data (Select Data)
#
# Tahap ini dilakukan dengan memilih atribut atau variabel yang relevan dengan tujuan analisis. Tidak semua data digunakan, hanya data yang benar-benar mendukung pencapaian tujuan data mining.
#
# - Membersihkan Data (Clean Data)
#
# Pada tahap ini dilakukan perbaikan terhadap data yang bermasalah, seperti menangani nilai kosong, menghapus data duplikat, serta memperbaiki kesalahan input. Tujuannya adalah meningkatkan kualitas data agar tidak memengaruhi hasil model.
#
# - Membangun Data (Construct Data)
#
# Tahap ini melibatkan pembuatan atribut baru atau transformasi variabel untuk meningkatkan informasi yang dapat digunakan model. Contohnya adalah menggabungkan beberapa variabel atau melakukan perhitungan tertentu.
#
# - Mengintegrasikan Data (Integrate Data)
#
# Pada tahap ini, data dari berbagai sumber digabungkan menjadi satu kesatuan yang konsisten. Proses ini penting jika data berasal dari lebih dari satu sistem atau database.
#
# - Memformat Data (Format Data)
#
# Tahap terakhir adalah menyesuaikan format data agar sesuai dengan kebutuhan algoritma, seperti melakukan normalisasi, encoding, atau pengubahan tipe data. Setelah tahap ini selesai, data siap digunakan dalam proses pemodelan.
#
# ## 4️⃣ Permodelan (Modeling)
# Modeling adalah tahap di mana data yang telah dipersiapkan digunakan untuk membangun model analisis sesuai dengan tujuan data mining. Pada tahap ini, berbagai algoritma diterapkan untuk menemukan pola atau membuat prediksi, kemudian hasilnya dievaluasi berdasarkan metrik yang telah ditentukan sebelumnya.
#
# - Memilih Teknik Pemodelan (Select Modeling Technique)
#
# Tahap ini dilakukan dengan menentukan metode atau algoritma yang sesuai dengan tujuan analisis, seperti klasifikasi, regresi, atau clustering. Pemilihan teknik harus disesuaikan dengan jenis permasalahan dan karakteristik data.
#
# - Merancang Proses Pengujian (Generate Test Design)
#
# Pada tahap ini ditentukan strategi pengujian model, seperti pembagian data menjadi data latih dan data uji. Tujuannya adalah memastikan model dapat diuji secara objektif dan tidak hanya bekerja baik pada data pelatihan saja.
#
# - Membangun Model (Build Model)
#
# Tahap ini merupakan proses penerapan algoritma pada data latih untuk menghasilkan model. Dalam proses ini dilakukan penyesuaian parameter agar model dapat bekerja secara optimal.
#
# - Mengevaluasi Model Secara Teknis (Assess Model)
#
# Pada tahap ini dilakukan pengukuran performa model menggunakan metrik evaluasi seperti akurasi, presisi, atau error rate. Hasil evaluasi ini menentukan apakah model sudah layak untuk dilanjutkan ke tahap berikutnya.
#
# ## 5️⃣ Penerapan (Deployment)
# Deployment adalah tahap akhir di mana model yang telah dibuat dan dievaluasi diimplementasikan ke dalam lingkungan nyata agar dapat digunakan untuk mendukung pengambilan keputusan bisnis. Tahap ini memastikan bahwa hasil analisis tidak hanya berhenti pada laporan, tetapi benar-benar memberikan manfaat bagi organisasi.
#
# - Merencanakan Implementasi (Plan Deployment)
#
# Tahap ini dilakukan dengan menyusun strategi penerapan model, termasuk menentukan bagaimana model akan digunakan, siapa yang akan mengoperasikan, serta sistem apa yang akan terlibat. Perencanaan yang baik membantu proses implementasi berjalan lancar.
#
# - Melakukan Implementasi Model (Deploy Model)
#
# Pada tahap ini, model diintegrasikan ke dalam sistem atau aplikasi yang digunakan perusahaan. Model dapat dijalankan secara otomatis maupun manual sesuai kebutuhan operasional.
#
# - Monitoring dan Pemeliharaan (Monitor and Maintain)
#
# Setelah diimplementasikan, model perlu dipantau secara berkala untuk memastikan kinerjanya tetap optimal. Jika terjadi perubahan pola data atau penurunan performa, maka model perlu diperbarui atau disesuaikan kembali.
